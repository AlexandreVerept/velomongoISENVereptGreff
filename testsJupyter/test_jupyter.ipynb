# %% [markdown]
# # Connections API vélo

# %% [markdown]
# ## Connector

# %%
import json
import requests
import pandas as pd

class api_connector():
    def get_api(self,url):
        response = requests.request("GET",url)
        response_json = json.loads(response.text.encode('utf-8'))
        return response_json.get("records",[])
    
    def get_lille(self):
        url = "https://opendata.lillemetropole.fr/api/records/1.0/search/?dataset=vlille-realtime&q=&rows=2000&facet=libelle&facet=nom&facet=commune&facet=etat&facet=type&facet=etatconnexion"
        return self.get_api(url)
    
    def get_rennes(self):
        url = "https://data.rennesmetropole.fr/api/records/1.0/search/?dataset=etat-des-stations-le-velo-star-en-temps-reel&q=&rows=2000&facet=nom&facet=etat&facet=nombreemplacementsactuels&facet=nombreemplacementsdisponibles&facet=nombrevelosdisponibles"
        return self.get_api(url)
    
    def get_lyon(self):
        url = "https://public.opendatasoft.com/api/records/1.0/search/?dataset=station-velov-grand-lyon&q=&rows=2000&facet=name&facet=commune&facet=bonus&facet=status&facet=available&facet=availabl_1&facet=availabili&facet=availabi_1&facet=last_upd_1"
        return self.get_api(url)
    
    def get_paris(self):
        url = "https://opendata.paris.fr/api/records/1.0/search/?dataset=velib-disponibilite-en-temps-reel&q=&rows=2000&facet=name&facet=is_installed&facet=is_renting&facet=is_returning&facet=nom_arrondissement_communes"
        return self.get_api(url)

# %%
ac = api_connector()

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Lille

# %%
dflille = pd.json_normalize(ac.get_lille())
dflille.head()
# Out:
#          datasetid                                  recordid  \
# 0  vlille-realtime  18b269166d31afbff1eaa73ca676067639cdbec7
# 1  vlille-realtime  e5decefb7f404a94fafd43a439835a1c6555f661
# 2  vlille-realtime  807e07d3f1e4fce53a1f1d7a458345896dc814ce
# 3  vlille-realtime  3a4d235ba0c3d7a46784090519e9a80384cba3ca
# 4  vlille-realtime  f4ab70778a3b8241b9a813ee27764ac3c9dbdbec
#
#                    record_timestamp   fields.etat fields.etatconnexion  \
# 0  2020-10-12T08:48:07.463000+00:00    EN SERVICE            CONNECTED
# 1  2020-10-12T08:48:07.463000+00:00    EN SERVICE            CONNECTED
# 2  2020-10-12T08:48:07.463000+00:00  HORS SERVICE         DISCONNECTED
# 3  2020-10-12T08:48:07.463000+00:00  HORS SERVICE         DISCONNECTED
# 4  2020-10-12T08:48:07.463000+00:00  HORS SERVICE         DISCONNECTED
#
#    fields.nbvelosdispo  fields.nbplacesdispo     fields.commune fields.type  \
# 0                   12                    12              LILLE    AVEC TPE
# 1                    0                     0  VILLENEUVE D'ASCQ    AVEC TPE
# 2                    0                    12            ROUBAIX    AVEC TPE
# 3                    0                     0    LILLE HELLEMMES    AVEC TPE
# 4                    0                     0          HELLEMMES    AVEC TPE
#
#    fields.libelle       fields.datemiseajour    fields.localisation  \
# 0              19  2020-10-12T08:46:03+00:00    [50.64031, 3.05774]
# 1             129  2019-10-21T07:46:05+00:00   [50.63608, 3.130853]
# 2             222  2019-07-10T15:47:05+00:00    [50.6941, 3.172165]
# 3              87  2019-07-10T15:39:06+00:00  [50.632393, 3.110669]
# 4             112  2019-07-10T15:40:06+00:00  [50.626846, 3.115101]
#
#                  fields.nom                    fields.adresse  \
# 0                RUE ROYALE                     40 RUE ROYALE
# 1             FLERS CHATEAU              RUE DE LA CHEVALERIE
# 2              LES GOBELINS  32, RUE DE LA COMMUNAUTÉ URBAINE
# 3              JULES GUESDE                       RUE ST ELOI
# 4  SQUARE CHARLES DE GAULLE          4, RUE FERDINAND BUISSON
#
#               fields.geo geometry.type   geometry.coordinates
# 0    [50.64031, 3.05774]         Point    [3.05774, 50.64031]
# 1   [50.63608, 3.130853]         Point   [3.130853, 50.63608]
# 2    [50.6941, 3.172165]         Point    [3.172165, 50.6941]
# 3  [50.632393, 3.110669]         Point  [3.110669, 50.632393]
# 4  [50.626846, 3.115101]         Point  [3.115101, 50.626846]

# %%
for col in dflille:
    print (col)
# Out:
# datasetid
# recordid
# record_timestamp
# fields.etat
# fields.etatconnexion
# fields.nbvelosdispo
# fields.nbplacesdispo
# fields.commune
# fields.type
# fields.libelle
# fields.datemiseajour
# fields.localisation
# fields.nom
# fields.adresse
# fields.geo
# geometry.type
# geometry.coordinates

# %% [markdown]
# ### Rennes

# %%
dfrennes = pd.json_normalize(ac.get_rennes())
dfrennes.head()
# Out:
#                                       datasetid  \
# 0  etat-des-stations-le-velo-star-en-temps-reel
# 1  etat-des-stations-le-velo-star-en-temps-reel
# 2  etat-des-stations-le-velo-star-en-temps-reel
# 3  etat-des-stations-le-velo-star-en-temps-reel
# 4  etat-des-stations-le-velo-star-en-temps-reel
#
#                                    recordid           record_timestamp  \
# 0  88a8871cd455b991aae541e2d60ebdab34840e3e  2020-10-12T08:47:00+00:00
# 1  b476b4248e499552a1449cb8afe72cc68c83c060  2020-10-12T08:47:00+00:00
# 2  bd0f83abcec2974fda4a9be7b78f4bfbb3af4b27  2020-10-12T08:47:00+00:00
# 3  bc23b982c96a853bb90665c1d574e7d9c204daed  2020-10-12T08:47:00+00:00
# 4  77cac0a1ecd7f2af56c8668b201afe2a20e1c6bb  2020-10-12T08:47:00+00:00
#
#          fields.etat          fields.lastupdate  \
# 0  En fonctionnement  2020-10-12T08:47:06+00:00
# 1  En fonctionnement  2020-10-12T08:47:06+00:00
# 2  En fonctionnement  2020-10-12T08:47:06+00:00
# 3  En fonctionnement  2020-10-12T08:47:06+00:00
# 4  En fonctionnement  2020-10-12T08:47:06+00:00
#
#    fields.nombrevelosdisponibles  fields.nombreemplacementsactuels  \
# 0                           11.0                              16.0
# 1                            7.0                              24.0
# 2                           16.0                              24.0
# 3                            9.0                              20.0
# 4                           18.0                              24.0
#
#          fields.nom  fields.nombreemplacementsdisponibles fields.idstation  \
# 0  Musée Beaux-Arts                                   5.0             5510
# 1     Champs Libres                                  17.0             5516
# 2    Brest - Verdun                                   8.0             5534
# 3           Marbeuf                                  11.0             5538
# 4    Plaine de Baud                                   6.0             5546
#
#        fields.coordonnees geometry.type    geometry.coordinates
# 0   [48.109601, -1.67408]         Point   [-1.67408, 48.109601]
# 1  [48.105537, -1.674328]         Point  [-1.674328, 48.105537]
# 2  [48.113009, -1.693264]         Point  [-1.693264, 48.113009]
# 3  [48.111749, -1.702077]         Point  [-1.702077, 48.111749]
# 4  [48.112461, -1.643674]         Point  [-1.643674, 48.112461]

# %%
for col in dfrennes:
    print (col)
# Out:
# datasetid
# recordid
# record_timestamp
# fields.etat
# fields.lastupdate
# fields.nombrevelosdisponibles
# fields.nombreemplacementsactuels
# fields.nom
# fields.nombreemplacementsdisponibles
# fields.idstation
# fields.coordonnees
# geometry.type
# geometry.coordinates

# %% [markdown]
# ### Lyon

# %%
dflyon = pd.json_normalize(ac.get_lyon())
dflyon.head()
# Out:
#                   datasetid                                  recordid  \
# 0  station-velov-grand-lyon  35a35fa3d3108e1305d37c7f7218897842a2a7ab
# 1  station-velov-grand-lyon  ee303eaa5ac1406821f4186a2118cb9b27005ae5
# 2  station-velov-grand-lyon  6763bd64aa006ea3a8855e24f303f979a45e3b95
# 3  station-velov-grand-lyon  c97904e4102ccaa62a939918d280bc81856418cd
# 4  station-velov-grand-lyon  64d00c6c5b0b212af83a7fccc3d6a90f79d4d783
#
#                    record_timestamp fields.available fields.status  \
# 0  2019-03-12T10:20:50.428000+00:00               23          OPEN
# 1  2019-03-12T10:20:50.428000+00:00                4          OPEN
# 2  2019-03-12T10:20:50.428000+00:00               12          OPEN
# 3  2019-03-12T10:20:50.428000+00:00                7          OPEN
# 4  2019-03-12T10:20:50.428000+00:00                0        CLOSED
#
#   fields.availabl_1             fields.name fields.commune fields.bonus  \
# 0                12         ZAC de la Buire     Lyon 3 ème          Non
# 1                16               Brotteaux     Lyon 6 ème          Non
# 2                 6       Place Sainte Anne     Lyon 3 ème          Non
# 3                 9      Lafayette / Créqui     Lyon 3 ème          Non
# 4                 0  Préssensé / 8 mai 1945   VILLEURBANNE          Non
#
#      fields.last_updat                  fields.address fields.bike_stand  \
# 0  2015-07-01 16:08:47  Face au 106 avenue Félix Faure                35
# 1  2015-07-01 16:04:00            17 place Jules Ferry                20
# 2  2015-07-01 16:05:24              2 place Saint Anne                18
# 3  2015-07-01 16:02:04                   Rue de Créqui                16
# 4  2015-07-01 16:07:03   294, rue Francis de Préssensé                16
#
#                        fields.geo_point_2d fields.availabili fields.number  \
# 0   [45.75379945822723, 4.859863339774901]                 1          3036
# 1  [45.768412261376376, 4.859070556738342]                 1          6008
# 2   [45.75695497472745, 4.865441659195344]                 1          3099
# 3   [45.76340457257395, 4.847137408952479]                 1          3032
# 4   [45.76918019445715, 4.896723707091346]                 0         10049
#
#   fields.banking fields.gid fields.nmarrond           fields.lat  \
# 0              t        952              36  45.7537994582273000
# 1              t        938               8  45.7684122613765000
# 2              t        940              99  45.7569549747275000
# 3              t        868              32  45.7634045725740000
# 4              t        869              49  45.7691801944572000
#
#   fields.geo_shape.type             fields.geo_shape.coordinates  \
# 0                 Point   [4.859863339774901, 45.75379945822723]
# 1                 Point  [4.859070556738342, 45.768412261376376]
# 2                 Point   [4.865441659195344, 45.75695497472745]
# 3                 Point   [4.847137408952479, 45.76340457257395]
# 4                 Point   [4.896723707091346, 45.76918019445715]
#
#            fields.lng fields.availabi_1    fields.last_upd_1 geometry.type  \
# 0  4.8598633397749000              Vert  2015-07-01 16:11:00         Point
# 1  4.8590705567383400              Vert  2015-07-01 16:11:00         Point
# 2  4.8654416591953500              Vert  2015-07-01 16:11:00         Point
# 3  4.8471374089524800              Vert  2015-07-01 16:11:00         Point
# 4  4.8967237070913500              Gris  2015-07-01 16:11:00         Point
#
#                       geometry.coordinates  \
# 0   [4.859863339774901, 45.75379945822723]
# 1  [4.859070556738342, 45.768412261376376]
# 2   [4.865441659195344, 45.75695497472745]
# 3   [4.847137408952479, 45.76340457257395]
# 4   [4.896723707091346, 45.76918019445715]
#
#                           fields.pole        fields.address2
# 0                                 NaN                    NaN
# 1  Métro, parking, place, restaurants                    NaN
# 2        Coeur de quartier, commerces                    NaN
# 3                                 NaN  Angle cours Lafayette
# 4               itinéraires cyclables                    NaN

# %%
for col in dflyon:
    print (col)
# Out:
# datasetid
# recordid
# record_timestamp
# fields.available
# fields.status
# fields.availabl_1
# fields.name
# fields.commune
# fields.bonus
# fields.last_updat
# fields.address
# fields.bike_stand
# fields.geo_point_2d
# fields.availabili
# fields.number
# fields.banking
# fields.gid
# fields.nmarrond
# fields.lat
# fields.geo_shape.type
# fields.geo_shape.coordinates
# fields.lng
# fields.availabi_1
# fields.last_upd_1
# geometry.type
# geometry.coordinates
# fields.pole
# fields.address2

# %% [markdown]
# ### Paris

# %%
dfparis = pd.json_normalize(ac.get_paris())
dfparis.head()
# Out:
#                            datasetid  \
# 0  velib-disponibilite-en-temps-reel
# 1  velib-disponibilite-en-temps-reel
# 2  velib-disponibilite-en-temps-reel
# 3  velib-disponibilite-en-temps-reel
# 4  velib-disponibilite-en-temps-reel
#
#                                    recordid                  record_timestamp  \
# 0  1d2f5955b486c79e8d23fcbec735a2aacf06a7b3  2020-10-12T08:48:06.575000+00:00
# 1  396cbda3157e4f1fff8b377dfbd37b206333dec9  2020-10-12T08:48:06.575000+00:00
# 2  90725a9bf0ad68c1a462a518d417d2b18537ad13  2020-10-12T08:48:06.575000+00:00
# 3  133c63159e871359b36348c15ace9a869525539c  2020-10-12T08:48:06.575000+00:00
# 4  96ae0216e54fcb9b26834897fbf4d7e1fc17b2f8  2020-10-12T08:48:06.575000+00:00
#
#    fields.ebike  fields.capacity                          fields.name  \
# 0             5               35        Benjamin Godard - Victor Hugo
# 1             9               55   André Mazet - Saint-André des Arts
# 2             1               20  Charonne - Robert et Sonia Delauney
# 3             8               46                Harpe - Saint-Germain
# 4             0               39         Guersant - Gouvion-Saint-Cyr
#
#   fields.nom_arrondissement_communes  fields.numbikesavailable  \
# 0                              Paris                         7
# 1                              Paris                        39
# 2                              Paris                         2
# 3                              Paris                        41
# 4                              Paris                         1
#
#   fields.is_installed fields.is_renting  fields.mechanical fields.stationcode  \
# 0                 OUI               OUI                  2              16107
# 1                 OUI               OUI                 30               6015
# 2                 OUI               OUI                  1              11104
# 3                 OUI               OUI                 33               5001
# 4                 OUI               OUI                  1              17041
#
#            fields.coordonnees_geo  fields.numdocksavailable  \
# 0           [48.865983, 2.275725]                        28
# 1  [48.8537558106, 2.33909580857]                        15
# 2   [48.855907556, 2.39257067442]                        18
# 3   [48.851518815, 2.34367031604]                         4
# 4  [48.8828777518, 2.28766737081]                        37
#
#               fields.duedate fields.is_returning geometry.type  \
# 0  2020-10-12T08:15:19+00:00                 OUI         Point
# 1  2020-10-12T08:14:25+00:00                 OUI         Point
# 2  2020-10-12T08:15:13+00:00                 OUI         Point
# 3  2020-10-12T08:14:29+00:00                 OUI         Point
# 4  2020-10-12T08:15:43+00:00                 OUI         Point
#
#              geometry.coordinates
# 0           [2.275725, 48.865983]
# 1  [2.33909580857, 48.8537558106]
# 2   [2.39257067442, 48.855907556]
# 3   [2.34367031604, 48.851518815]
# 4  [2.28766737081, 48.8828777518]

# %%
for col in dfparis:
    print (col)
# Out:
# datasetid
# recordid
# record_timestamp
# fields.ebike
# fields.capacity
# fields.name
# fields.nom_arrondissement_communes
# fields.numbikesavailable
# fields.is_installed
# fields.is_renting
# fields.mechanical
# fields.stationcode
# fields.coordonnees_geo
# fields.numdocksavailable
# fields.duedate
# fields.is_returning
# geometry.type
# geometry.coordinates

# %% [markdown]
# ## Clean
#
# On nettoie les datasets pour les placer dans la collection d'abri à vélo avec les informations suivantes:
#
# geolocations, size, name, tpe, available

# %%
def clean_lille(dflille):
    dflilleclean = dflille[['fields.nom','fields.geo','fields.type','fields.etat']].drop_duplicates(subset=['fields.nom'])
    dflilleclean = dflilleclean.rename(columns={'fields.nom':'Name','fields.geo':'Geo','fields.type':'TPE','fields.etat':'Available'})
    
    # get the size of Lille Stations by adding the number of availables places and bicycles
    size = []
    for i, row in dflille.iterrows():
        size.append(row['fields.nbvelosdispo']+row['fields.nbplacesdispo'])

    dflilleclean = pd.concat([dflilleclean,pd.DataFrame(size, columns = ['Size'])], axis=1, join='inner')

    # set the 'tpe' column with boolean
    dflilleclean['TPE'] = dflilleclean['TPE'].replace("AVEC TPE","True")
    dflilleclean['TPE'] = dflilleclean['TPE'].replace("SANS TPE","False")

    # set the 'Available' column with boolean
    dflilleclean['Available'] = dflilleclean['Available'].replace("EN SERVICE","True")

    for i, row in dflilleclean.iterrows():
        if not row['Available'] == 'True':
            dflilleclean['Available'].loc[i] = 'False'
            
    return(dflilleclean)

dflilleclean = clean_lille(dflille)
dflilleclean.head()
# Out:
# C:\Users\avere\.conda\envs\velomongo\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
#                        Name                    Geo   TPE Available  Size
# 0                RUE ROYALE    [50.64031, 3.05774]  True      True    24
# 1             FLERS CHATEAU   [50.63608, 3.130853]  True      True     0
# 2              LES GOBELINS    [50.6941, 3.172165]  True     False    12
# 3              JULES GUESDE  [50.632393, 3.110669]  True     False     0
# 4  SQUARE CHARLES DE GAULLE  [50.626846, 3.115101]  True     False     0

# %%
def clean_rennes(dfrennes):
    dfrennesclean = dfrennes[["fields.nom","fields.coordonnees","fields.etat","fields.nombreemplacementsactuels"]].drop_duplicates(subset=['fields.nom'])
    dfrennesclean = dfrennesclean.rename(columns={'fields.nom':'Name','fields.coordonnees':'Geo','fields.type':'TPE','fields.etat':'Available','fields.nombreemplacementsactuels':'Size'})

    # set the 'Available' column with boolean
    dfrennesclean['Available'] = dfrennesclean['Available'].replace("En fonctionnement","True")

    for i, row in dfrennesclean.iterrows():
        if not row['Available'] == 'True':
            dfrennesclean['Available'].loc[i] = 'False'
        
    return(dfrennesclean)

dfrennesclean = clean_rennes(dfrennes)
dfrennesclean.head()
# Out:
# C:\Users\avere\.conda\envs\velomongo\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
#                Name                     Geo Available  Size
# 0  Musée Beaux-Arts   [48.109601, -1.67408]      True  16.0
# 1     Champs Libres  [48.105537, -1.674328]      True  24.0
# 2    Brest - Verdun  [48.113009, -1.693264]      True  24.0
# 3           Marbeuf  [48.111749, -1.702077]      True  20.0
# 4    Plaine de Baud  [48.112461, -1.643674]      True  24.0

# %%
dflyon.head()
# Out:
#                   datasetid                                  recordid  \
# 0  station-velov-grand-lyon  35a35fa3d3108e1305d37c7f7218897842a2a7ab
# 1  station-velov-grand-lyon  ee303eaa5ac1406821f4186a2118cb9b27005ae5
# 2  station-velov-grand-lyon  6763bd64aa006ea3a8855e24f303f979a45e3b95
# 3  station-velov-grand-lyon  c97904e4102ccaa62a939918d280bc81856418cd
# 4  station-velov-grand-lyon  64d00c6c5b0b212af83a7fccc3d6a90f79d4d783
#
#                    record_timestamp fields.available fields.status  \
# 0  2019-03-12T10:20:50.428000+00:00               23          OPEN
# 1  2019-03-12T10:20:50.428000+00:00                4          OPEN
# 2  2019-03-12T10:20:50.428000+00:00               12          OPEN
# 3  2019-03-12T10:20:50.428000+00:00                7          OPEN
# 4  2019-03-12T10:20:50.428000+00:00                0        CLOSED
#
#   fields.availabl_1             fields.name fields.commune fields.bonus  \
# 0                12         ZAC de la Buire     Lyon 3 ème          Non
# 1                16               Brotteaux     Lyon 6 ème          Non
# 2                 6       Place Sainte Anne     Lyon 3 ème          Non
# 3                 9      Lafayette / Créqui     Lyon 3 ème          Non
# 4                 0  Préssensé / 8 mai 1945   VILLEURBANNE          Non
#
#      fields.last_updat                  fields.address fields.bike_stand  \
# 0  2015-07-01 16:08:47  Face au 106 avenue Félix Faure                35
# 1  2015-07-01 16:04:00            17 place Jules Ferry                20
# 2  2015-07-01 16:05:24              2 place Saint Anne                18
# 3  2015-07-01 16:02:04                   Rue de Créqui                16
# 4  2015-07-01 16:07:03   294, rue Francis de Préssensé                16
#
#                        fields.geo_point_2d fields.availabili fields.number  \
# 0   [45.75379945822723, 4.859863339774901]                 1          3036
# 1  [45.768412261376376, 4.859070556738342]                 1          6008
# 2   [45.75695497472745, 4.865441659195344]                 1          3099
# 3   [45.76340457257395, 4.847137408952479]                 1          3032
# 4   [45.76918019445715, 4.896723707091346]                 0         10049
#
#   fields.banking fields.gid fields.nmarrond           fields.lat  \
# 0              t        952              36  45.7537994582273000
# 1              t        938               8  45.7684122613765000
# 2              t        940              99  45.7569549747275000
# 3              t        868              32  45.7634045725740000
# 4              t        869              49  45.7691801944572000
#
#   fields.geo_shape.type             fields.geo_shape.coordinates  \
# 0                 Point   [4.859863339774901, 45.75379945822723]
# 1                 Point  [4.859070556738342, 45.768412261376376]
# 2                 Point   [4.865441659195344, 45.75695497472745]
# 3                 Point   [4.847137408952479, 45.76340457257395]
# 4                 Point   [4.896723707091346, 45.76918019445715]
#
#            fields.lng fields.availabi_1    fields.last_upd_1 geometry.type  \
# 0  4.8598633397749000              Vert  2015-07-01 16:11:00         Point
# 1  4.8590705567383400              Vert  2015-07-01 16:11:00         Point
# 2  4.8654416591953500              Vert  2015-07-01 16:11:00         Point
# 3  4.8471374089524800              Vert  2015-07-01 16:11:00         Point
# 4  4.8967237070913500              Gris  2015-07-01 16:11:00         Point
#
#                       geometry.coordinates  \
# 0   [4.859863339774901, 45.75379945822723]
# 1  [4.859070556738342, 45.768412261376376]
# 2   [4.865441659195344, 45.75695497472745]
# 3   [4.847137408952479, 45.76340457257395]
# 4   [4.896723707091346, 45.76918019445715]
#
#                           fields.pole        fields.address2
# 0                                 NaN                    NaN
# 1  Métro, parking, place, restaurants                    NaN
# 2        Coeur de quartier, commerces                    NaN
# 3                                 NaN  Angle cours Lafayette
# 4               itinéraires cyclables                    NaN

# %%
def clean_lyon(dflyon):
    dflyonclean = dflyon[["fields.name","fields.geo_shape.coordinates","fields.status","fields.bike_stand"]].drop_duplicates(subset=['fields.name'])
    dflyonclean = dflyonclean.rename(columns={'fields.name':'Name','fields.geo_shape.coordinates':'Geo','fields.status':'Available','fields.bike_stand':'Size'})

    # set the 'Available' column with boolean
    dflyonclean['Available'] = dflyonclean['Available'].replace("OPEN","True")

    for i, row in dflyonclean.iterrows():
        if not row['Available'] == 'True':
            dflyonclean['Available'].loc[i] = 'False'
    
    return(dflyonclean)

dflyonclean = clean_lyon(dflyon)
dflyonclean.head()
# Out:
#                      Name                                      Geo Available  \
# 0         ZAC de la Buire   [4.859863339774901, 45.75379945822723]      True
# 1               Brotteaux  [4.859070556738342, 45.768412261376376]      True
# 2       Place Sainte Anne   [4.865441659195344, 45.75695497472745]      True
# 3      Lafayette / Créqui   [4.847137408952479, 45.76340457257395]      True
# 4  Préssensé / 8 mai 1945   [4.896723707091346, 45.76918019445715]     False
#
#   Size
# 0   35
# 1   20
# 2   18
# 3   16
# 4   16

# %%
def clean_paris(dfparis):
    dfparisclean = dfparis[["fields.name","fields.coordonnees_geo","fields.is_renting","fields.capacity"]].drop_duplicates(subset=['fields.name'])
    dfparisclean = dfparisclean.rename(columns={'fields.name':'Name','fields.coordonnees_geo':'Geo','fields.is_renting':'Available','fields.capacity':'Size'})

    # set the 'Available' column with boolean
    dfparisclean['Available'] = dfparisclean['Available'].replace("OUI","True")

    for i, row in dfparisclean.iterrows():
        if not row['Available'] == 'True':
            dfparisclean['Available'].loc[i] = 'False'
            
    return(dfparisclean)
            
dfparisclean = clean_paris(dfparis)
dfparisclean.head()
# Out:
# C:\Users\avere\.conda\envs\velomongo\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
#                                   Name                             Geo  \
# 0        Benjamin Godard - Victor Hugo           [48.865983, 2.275725]
# 1   André Mazet - Saint-André des Arts  [48.8537558106, 2.33909580857]
# 2  Charonne - Robert et Sonia Delauney   [48.855907556, 2.39257067442]
# 3                Harpe - Saint-Germain   [48.851518815, 2.34367031604]
# 4         Guersant - Gouvion-Saint-Cyr  [48.8828777518, 2.28766737081]
#
#   Available  Size
# 0      True    35
# 1      True    55
# 2      True    20
# 3      True    46
# 4      True    39

# %%
len(dflilleclean)+len(dfrennesclean)+len(dflyonclean)+len(dfparisclean)
# Out:
# 2044

# %% [markdown]
# ### Concat

# %%
dfall = pd.concat([dflilleclean,dfrennesclean,dflyonclean,dfparisclean],ignore_index=True)

# %%
dfall.head()
# Out:
#                        Name                    Geo   TPE Available Size
# 0                RUE ROYALE    [50.64031, 3.05774]  True      True   24
# 1             FLERS CHATEAU   [50.63608, 3.130853]  True      True    0
# 2              LES GOBELINS    [50.6941, 3.172165]  True     False   12
# 3              JULES GUESDE  [50.632393, 3.110669]  True     False    0
# 4  SQUARE CHARLES DE GAULLE  [50.626846, 3.115101]  True     False    0
